# %% [markdown]
# ### Assignment: Arithmetic Operators
#
# Take two numbers as input from the user and:
# - Calculate their sum
# - Calculate their difference
# - Calculate their product
# - Calculate their remainder

# %%
a=int(input("enter a number"))
b=int(input("enter 2nd number"))
print(a,b)
sum=a+b
diff=a-b
mul=a*b
div=a/b
mod=a%b
print(sum)
print(diff)
print(mul)
print(div)
print(mod)
# Out:
# 20 5
# 25
# 15
# 100
# 4.0
# 0

# %% [markdown]
# ### Assignment: Assignment Operators
#
# Create a variable with an initial value and use assignment operators (`+=`, `-=`, `*=`) to update the value step by step.

# %%
a=int(input("enter a number"))
print(a)
a+=2
print(a)
a-=1
print(a)
a*=3
print(a)
# Out:
# 7
# 9
# 8
# 24

# %% [markdown]
# ### Assignment: Logical Operators
#
# Take two boolean values and:
# - Check the result using `and`
# - Check the result using `or`
# - Reverse one value using `not`

# %%
n1=int(input("enter a no"))
n2=int(input("enter another no"))
print(n1,n2)

print(n1 and n2)
print(n1 or n2)
print(not(n1))
# Out:
# 2 3
# 3
# 2
# False

# %% [markdown]
# ### Assignment: Bitwise Operators
#
# Take two integers and perform:
# - Bitwise AND
# - Bitwise OR
# - Bitwise XOR

# %%
i1=int(input("integer 1"))
i2=int(input("integer 2"))
print(i1,i2)
print(i1&i2)
print(i1|i2)
print(i1^i2)
# Out:
# 1 2
# 0
# 3
# 3

# %% [markdown]
# ### Assignment: Comparison Operators
#
# Take two numbers as input from the user and:
# - Check if both numbers are equal
# - Check which number is greater
# - Check which number is smaller

# %%
a1=int(input("enter no 1"))
a2=int(input("enter no 2"))
print(a1,a2)
print(a1==a2)
print(a1>=a2)
print(a2>a1)
print(a1<a2)
print(a2<a1)
# Out:
# 2 3
# False
# False
# True
# True
# False

# %% [markdown]
# ### 📝 Task 1: Electricity Bill Calculator
#
# Write a Python program that:
#
# - Takes the total number of electricity units consumed as input
# - Calculates the total electricity bill using slab-wise conditions
# - Displays the final payable amount in **NPR**
# if unit is less than 5 then price is 5 per unit, if unit is more than 5 less than 10 then price per unit is 10 if more than 10 then price is 15 per units

# %%
elcunit=int(input("total number of electricity units consumed:"))

if elcunit<5:
    total_amount=5*elcunit

elif elcunit>=5 and elcunit<=10:
    total_amount=10*elcunit

else:
    total_amount=15*elcunit
    
print("Your Unit of total electricity consumption is :",elcunit)
print("final amount to pay:NPR",total_amount)
# Out:
# Your Unit of total electricity consumption is : 4
# final amount to pay:NPR 20

# %% [markdown]
# ### 📝 Task 2: ATM Withdrawal System
#
# Write a Python program that:
#
# - Initializes an account balance of **NPR 25,000**
# - Takes the withdrawal amount as input from the user
# - Allows withdrawal only if:
#   - The withdrawal amount is a multiple of **500**
#   - The remaining balance is not less than **NPR 1,000**
# - Displays appropriate messages for successful or failed transactions

# %%
acc_balance=25000;
wthdrw=int(input("Mention amount of withdrawal:"))

if(wthdrw%500!=0):
    print("!withdraw amount invalid!")

elif acc_balance-wthdrw<1000:
     
 elif (new_balance<1000):
       print("Sorry,Withdraw not possible,please check on your current balance")
     else:
       print("Amount withdraw successful!New Balance is",new_balance)
# Out:
# !withdraw amount invalid!

# %% [markdown]
# ### 📝 Task 3: Number Pattern Using Loops
#
# Write a Python program using loops to generate the following pattern:
#
# 1 \
# 12 \
# 123 \
# 1234 \
# 12345

# %%
pattern=(1,2,3,4,5)
for i in range(5):
    for j in range(i+1):
        print(pattern[j], end="")
    print()
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %% [markdown]
# ### 📝 Task 4: Student Grade Evaluation Function
#
# Write a Python function that:
#
# - Accepts marks of **five subjects** as input
# - Calculates the average marks
# - Returns the grade based on the average score

# %%
print("enter marks obtained in:")
maths=int(input("enter marks of maths:"))
ecom=int(input("ecom:"))
ds=int(input("ds:"))
sad=int(input("sad:"))
web=int(input("web:"))

total_marks=maths+ecom+ds+sad+web
avg_marks=total_marks/5;
print(avg_marks)

if avg_marks>=90 and avg_marks<=100:
   print("Grade: 'A' ")
elif avg_marks>=80 and avg_marks<90:
   print("Grade: 'A-' ")
elif avg_marks>=70 and avg_marks<80:
   print("Grade: 'B' ")
elif avg_marks>=60 and avg_marks<70:
   print("Grade: 'B-' ")
elif avg_marks>=50 and avg_marks<60:
   print("Grade: 'C+' ")
elif avg_marks>=40 and avg_marks<50:
   print("Grade: 'C' ")
elif avg_marks>=35 and avg_marks<40:
   print("Grade: 'C-' ")
else:
   print("Not Graded")
# Out:
# enter marks obtained in:
# 4.0
# Not Graded

# %% [markdown]
# ### 📝 Task 5: Menu-Driven Calculator Using Functions
#
# Write a Python program that:
#
# - Uses separate functions for:
#   - Addition
#   - Subtraction
#   - Multiplication
#   - Division
# - Displays a menu to the user
# - Performs the selected operation
# - Repeats until the user chooses to exit

# %%
i=int(input("type a number to perform an operation:\n 1:addition,2:substraction,3:multiplication,4:division,5:exit"))
in1=int(input("enter a"))
in2=int(input("enter b"))
print(in1,in2)

print("operation ",i) 
if i==1:
 def ad(a,b):
    result=a+b
    print("addition:",result)
 ad(in1,in2)

elif i==2:
 def sub(a,b):
    result=a-b
    print("difference:",result)
 sub(in1,in2)

elif i==3:
 def mul(a,b):
    result=a*b
    print("multiplication:",result)
 mul(in1,in2)

elif i==4:
 def div(a,b):
    result=a/b
    print("division:",result)
 div(in1,in2)

else:
  print("exit:done")
# Out:
# 5 10
# operation  4
# division: 0.5

# %% [markdown]
# ### 📝 Task 6: Lambda Function Practice
#
# Using **lambda functions**, write programs to:
#
# - Check whether a number is even or odd
# - Find the maximum of two numbers
# - Calculate the cube of a given number

# %%
a=int(input("enter a number"))
no=lambda a:a%2==0

if no(a):
   print ("even")
else:
   print("odd")
# Out:
# odd

# %%
#max of two numbers:
x=int(input("enter a number"))
y=int(input("enter another number"))

max=lambda x,y: x if x>y else y
print(max(x,y))
# Out:
# 3

# %%
cube=lambda x:x*x*x
print(cube(5))
# Out:
# 125

# %% [markdown]
# ### 📝 Task 7: Safe User Input Handling
#
# Write a Python program that:
#
# - Takes age as input from the user
# - Handles invalid inputs such as:
#   - Non-numeric values
#   - Negative numbers
# - Displays appropriate error messages using exception handling

# %%
try:
 age=int(input("enter your age:"))
 if age<0:
      print("age cant be negative")
 else:
      print("the age is",age)
except ValueError:
     print("Error! Age cant be non numeric")
# Out:
# Error!age cant be non numeric

# %% [markdown]
# ### 📝 Task 8: Banking System Error Handling
#
# Write a Python function `withdraw()` that:
#
# - Accepts balance and withdrawal amount as input
# - Raises an error if the withdrawal amount is greater than the balance
# - Handles invalid inputs using `try-except` blocks

# %%
def withdraw():
    try:
        acc = int(input("Enter account balance: "))
        withbal = int(input("Enter withdraw amount: "))

        if withbal > acc:  
            print("Error!! Withdraw not possible")
        else:
            acc -= withbal
            print("Withdraw successful, new account balance:", acc)

    except ValueError:
        print("Invalid input!! Please enter numeric values only.")

withdraw()
# Out:
# Invalid input!! Please enter numeric values only.
